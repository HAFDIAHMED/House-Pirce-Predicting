# %% [markdown]
# # House Price Prediction

# %% [markdown]
# <center>
#     <img src="https://miro.medium.com/max/1280/1*FN5pcQ-OcLkxgHwMzqZABA.jpeg"/>
# </center>

# %% [raw]
# Build Two models of machine learning ( Linear Regression and Polynomial Regression ) to predict the house price .

# %% [markdown]
# Loading the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %% [markdown]
# # Importing Data Sets

# %%
url ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/kc_house_data_NaN.csv"
data=pd.read_csv(url)

# %%
data.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21600.000000  21603.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.372870      2.115736
# std     6239.28002  2.876566e+09  3.671272e+05      0.926657      0.768996
# min        0.00000  1.000102e+06  7.500000e+04      1.000000      0.500000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     21613 non-null  int64
#  1   id             21613 non-null  int64
#  2   date           21613 non-null  object
#  3   price          21613 non-null  float64
#  4   bedrooms       21600 non-null  float64
#  5   bathrooms      21603 non-null  float64
#  6   sqft_living    21613 non-null  int64
#  7   sqft_lot       21613 non-null  int64
#  8   floors         21613 non-null  float64
#  9   waterfront     21613 non-null  int64
#  10  view           21613 non-null  int64
#  11  condition      21613 non-null  int64
#  12  grade          21613 non-null  int64
#  13  sqft_above     21613 non-null  int64
#  14  sqft_basement  21613 non-null  int64
#  15  yr_built       21613 non-null  int64
#  16  yr_renovated   21613 non-null  int64
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0        0
# id                0
# date              0
# price             0
# bedrooms         13
# bathrooms        10
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view              0
# condition         0
# grade             0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# yr_renovated      0
# zipcode           0
# lat               0
# long              0
# sqft_living15     0
# sqft_lot15        0
# dtype: int64

# %% [markdown]
# # Data Wrangling

# %% [raw]
# let's drop the columns "id" and "Unnamed"

# %%
data.drop(["id","Unnamed: 0"],axis=1,inplace=True)

# %%
data.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0       3.0       1.00         1180      5650
# 1  20141209T000000  538000.0       3.0       2.25         2570      7242
# 2  20150225T000000  180000.0       2.0       1.00          770     10000
# 3  20141209T000000  604000.0       4.0       3.00         1960      5000
# 4  20150218T000000  510000.0       3.0       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
data.isna().sum()
# Out:
# date              0
# price             0
# bedrooms         13
# bathrooms        10
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view              0
# condition         0
# grade             0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# yr_renovated      0
# zipcode           0
# lat               0
# long              0
# sqft_living15     0
# sqft_lot15        0
# dtype: int64

# %% [raw]
# The columns "bedrooms" and "bathrooms" have missied values . we can deal with muissing values by replacing the null values with the mean .

# %%
mean_bedrooms=data["bedrooms"].mean()
print(mean_bedrooms)
# Out:
# 3.37287037037037

# %%
mean_bathrooms=data["bathrooms"].mean()
print(mean_bathrooms)
# Out:
# 2.1157362403369904

# %%
data["bedrooms"].replace(np.nan,mean_bedrooms,inplace=True)

# %%
data["bathrooms"].replace(np.nan,mean_bathrooms,inplace=True)

# %%
data.isna().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308797   0.525738     0.702035  0.089661  0.256794
# bedrooms       0.308797  1.000000   0.514194     0.578077  0.032307  0.178022
# bathrooms      0.525738  0.514194   1.000000     0.755371  0.087929  0.502132
# sqft_living    0.702035  0.578077   0.755371     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.032307   0.087929     0.172826  1.000000 -0.005201
# floors         0.256794  0.178022   0.502132     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006800   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.080058   0.188341     0.284611  0.074710  0.029444
# condition      0.036362  0.026690  -0.126197    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356589   0.664676     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.479286   0.686309     0.876597  0.183512  0.523885
# ...

# %%
data[["price","bedrooms"]].corr()
# Out:
#              price  bedrooms
# price     1.000000  0.308797
# bedrooms  0.308797  1.000000

# %%
data[["price","bathrooms"]].corr()
# Out:
#               price  bathrooms
# price      1.000000   0.525738
# bathrooms  0.525738   1.000000

# %%
data[["price","sqft_living"]].corr()
# Out:
#                 price  sqft_living
# price        1.000000     0.702035
# sqft_living  0.702035     1.000000

# %%
x=data["price"]
y=data["sqft_living"]
plt.plot(y,x)
plt.xlabel("sqft_living")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# # Model Developpement

# %% [raw]
# Build a Linear Regression Model to predict the Price using the "sqft_living"

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
Model_LR=LinearRegression()

# %%
X=data[["sqft_living"]]
Y=data[["price"]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
Model_LR.fit(X,Y)
# Out:
# LinearRegression()

# %%
Y_hat=Model_LR.predict(X_test)

# %%
plt.plot(X_test,Y_hat)

# %%
plt.plot(X_test,Y_test)

# %%
Model_LR.score(X,Y)
# Out:
# 0.4928532179037931

# %% [raw]
# Build a  Ridge Regression Model to predict the Price using these features :"floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"

# %%
features = ["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]

# %%
Y=data[["price"]]
X=data[features]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import Ridge

# %%
Model_Ridge=Ridge(alpha=0.1)

# %%
Model_Ridge.fit(X,Y)
# Out:
# Ridge(alpha=0.1)

# %%
Y_hat=Model_Ridge.predict(X_test)

# %%
Model_Ridge.score(X,Y)
# Out:
# 0.6576951534165589

# %% [markdown]
# # Model Evaluation

# %%
for the linear regression we got  the score about 0.4928532179037931 , so the model is not doing a good job , the model is not appropriate .

# %% [markdown]
# # Feedback
